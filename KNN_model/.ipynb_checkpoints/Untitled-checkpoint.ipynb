# %%
import pandas as pd

# %%
df = pd.read_csv("tiktok_dataset.csv")
df
# Out:
#      gender  age    follow
# 0      male   40    male_f
# 1      male   17  female_t
# 2      male   35    male_t
# 3    female   22    male_f
# 4    female   34    male_t
# ..      ...  ...       ...
# 395    male   31  female_t
# 396  female   39  female_t
# 397    male   31  female_t
# 398  female   44  female_t
# 399    male   30  female_t
#
# [400 rows x 3 columns]

# %%
df["gender"]
# Out:
# 0        male
# 1        male
# 2        male
# 3      female
# 4      female
#         ...
# 395      male
# 396    female
# 397      male
# 398    female
# 399      male
# Name: gender, Length: 400, dtype: object

# %%
#gender = ["male", "female"]

# %%
for i in range(0, len(df["gender"])):
    if df["gender"][i] == "male":
        df["gender"][i] = 0
    else:
        df["gender"][i] = 1
df["gender"]
# Out:
# <ipython-input-6-b747f0e74baf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"][i] = 0
# <ipython-input-6-b747f0e74baf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"][i] = 1
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 395    0
# 396    1
# 397    0
# 398    1
# 399    0
# Name: gender, Length: 400, dtype: object

# %%
df
# Out:
#     gender  age    follow
# 0        0   40    male_f
# 1        0   17  female_t
# 2        0   35    male_t
# 3        1   22    male_f
# 4        1   34    male_t
# ..     ...  ...       ...
# 395      0   31  female_t
# 396      1   39  female_t
# 397      0   31  female_t
# 398      1   44  female_t
# 399      0   30  female_t
#
# [400 rows x 3 columns]

# %%
#follow = ["male_t", "male_f", "female_t", "female_f"]

for i in range(0, len(df["follow"])):
    if df["follow"][i] == "male_t":
        df["follow"][i] = 0
    if df["follow"][i] == "male_f":
        df["follow"][i] = 1
    if df["follow"][i] == "female_t":
        df["follow"][i] = 0
    if df["follow"][i] == "female_f":
        df["follow"][i] = 1
# Out:
# <ipython-input-8-deb8db439e7b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["follow"][i] = 1
# <ipython-input-8-deb8db439e7b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["follow"][i] = 0
# <ipython-input-8-deb8db439e7b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["follow"][i] = 0
# <ipython-input-8-deb8db439e7b>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["follow"][i] = 1

# %%
df.to_csv("tiktok_dataset_index", index = False)
# Out:
#     gender  age follow
# 0        0   40      1
# 1        0   17      0
# 2        0   35      0
# 3        1   22      1
# 4        1   34      0
# ..     ...  ...    ...
# 395      0   31      0
# 396      1   39      0
# 397      0   31      0
# 398      1   44      0
# 399      0   30      0
#
# [400 rows x 3 columns]

# %%
d0 = df[df.follow == 0]
d1 = df[df.follow == 1]
#d2 = df[df.follow == 2]
#d3 = df[df.follow == 3]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel('gender')
plt.ylabel('age')
plt.scatter(d0['gender'], d0['age'],color="green",marker='+')
plt.scatter(d1['gender'], d1['age'],color="blue",marker='.')
#plt.scatter(d2['gender'], d2['age'],color="red",marker='+')
#plt.scatter(d3['gender'], d3['age'],color="black",marker='.')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['follow'], axis='columns')
y = df.follow

len(X)
# Out:
# 400

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
len(X_train)
# Out:
# 320

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %%
# create model KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-b51b1ba68fe1> in <module>
#       2 from sklearn.neighbors import KNeighborsClassifier
#       3 knn = KNeighborsClassifier(n_neighbors=2)
# ----> 4 knn.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     177             The fitted k-nearest neighbors classifier.
#     178         """
# --> 179         return self._fit(X, y)
#     180
#     181     def predict(self, X):
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     379                     self.outputs_2d_ = True
#     380
# --> 381                 check_classification_targets(y)
#     382                 self.classes_ = []
#     383                 self._y = np.empty(y.shape, dtype=int)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'unknown'
