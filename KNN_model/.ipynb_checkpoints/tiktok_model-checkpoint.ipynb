# %%
import numpy as np
import pandas as pd
import random

# %%
gender = ["male", "female"]

# %%
means = ["male_t", "male_f", "female_t", "female_f"]

# %%
arr1 = []
arr2 = []
arr3 = []
for i in range(0, 400):
    arr1.append(gender[random.randrange(0,2)])
    arr2.append(random.randrange(16,50))
    arr3.append(means[random.randrange(0,4)])

# %%
data = {
    'gender': arr1,
    'age': arr2,
    'follow': arr3,
}

# %%
data
# Out:
# {'gender': ['male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male',
#   'male'],
#  'age': [26,
#   29,
#   34,
#   25,
#   42,
#   45,
#   32,
#   44,
#   44,
#   21,
#   16,
#   36,
#   38,
#   18,
#   41,
#   28,
#   18,
#   37,
#   23,
#   20,
#   44,
#   20,
#   47,
#   45,
#   46,
#   45,
#   34,
#   27,
#   21,
#   45,
#   42,
#   46,
#   31,
#   18,
#   18,
#   48,
#   16,
#   25,
#   18,
#   35,
#   32,
#   26,
#   19,
#   16,
#   35,
#   43,
#   48,
#   28,
#   30,
#   32,
#   19,
#   37,
#   47,
#   25,
#   32,
#   39,
#   19,
#   20,
#   23,
#   34,
#   43,
#   47,
#   16,
#   17,
#   26,
#   36,
#   22,
#   39,
#   41,
#   17,
#   27,
#   25,
#   42,
#   33,
#   47,
#   29,
#   49,
#   19,
#   32,
#   26,
#   39,
#   33,
#   27,
#   30,
#   28,
#   48,
#   34,
#   30,
#   37,
#   46,
#   30,
#   35,
#   18,
#   16,
#   47,
#   21,
#   39,
#   33,
#   36,
#   40,
#   44,
#   18,
#   48,
#   31,
#   32,
#   16,
#   38,
#   29,
#   31,
#   47,
#   24,
#   35,
#   49,
#   16,
#   24,
#   35,
#   41,
#   27,
#   49,
#   40,
#   31,
#   39,
#   29,
#   17,
#   18,
#   22,
#   18,
#   44,
#   18,
#   22,
#   32,
#   29,
#   48,
#   42,
#   21,
#   25,
#   22,
#   47,
#   37,
#   49,
#   47,
#   43,
#   43,
#   41,
#   30,
#   34,
#   19,
#   45,
#   22,
#   40,
#   29,
#   34,
#   46,
#   46,
#   30,
#   35,
#   37,
#   18,
#   41,
#   41,
#   49,
#   32,
#   47,
#   35,
#   44,
#   32,
#   42,
#   39,
#   38,
#   42,
#   25,
#   40,
#   44,
#   39,
#   28,
#   45,
#   41,
#   32,
#   29,
#   25,
#   29,
#   16,
#   43,
#   33,
#   16,
#   37,
#   28,
#   18,
#   48,
#   28,
#   49,
#   19,
#   47,
#   16,
#   41,
#   21,
#   40,
#   19,
#   28,
#   22,
#   18,
#   23,
#   23,
#   28,
#   47,
#   21,
#   42,
#   44,
#   37,
#   30,
#   33,
#   17,
#   29,
#   26,
#   39,
#   36,
#   22,
#   28,
#   39,
#   31,
#   41,
#   18,
#   30,
#   23,
#   25,
#   20,
#   40,
#   48,
#   34,
#   31,
#   26,
#   33,
#   27,
#   28,
#   24,
#   33,
#   42,
#   48,
#   42,
#   17,
#   41,
#   35,
#   35,
#   40,
#   22,
#   21,
#   44,
#   20,
#   47,
#   29,
#   47,
#   37,
#   44,
#   25,
#   26,
#   22,
#   16,
#   24,
#   28,
#   33,
#   35,
#   44,
#   26,
#   43,
#   49,
#   17,
#   32,
#   25,
#   29,
#   36,
#   47,
#   25,
#   34,
#   45,
#   31,
#   16,
#   31,
#   16,
#   46,
#   48,
#   48,
#   32,
#   32,
#   30,
#   16,
#   17,
#   46,
#   43,
#   46,
#   34,
#   36,
#   43,
#   36,
#   16,
#   23,
#   48,
#   19,
#   24,
#   28,
#   43,
#   36,
#   29,
#   35,
#   40,
#   37,
#   46,
#   25,
#   24,
#   44,
#   41,
#   35,
#   20,
#   30,
#   42,
#   22,
#   21,
#   32,
#   42,
#   25,
#   42,
#   21,
#   40,
#   32,
#   46,
#   24,
#   48,
#   24,
#   17,
#   32,
#   24,
#   16,
#   33,
#   29,
#   43,
#   46,
#   48,
#   27,
#   38,
#   25,
#   16,
#   35,
#   24,
#   38,
#   26,
#   46,
#   32,
#   19,
#   27,
#   42,
#   22,
#   34,
#   35,
#   47,
#   46,
#   42,
#   29,
#   47,
#   39,
#   23,
#   41,
#   45,
#   35,
#   17,
#   21,
#   31,
#   24,
#   27,
#   27,
#   30,
#   41,
#   24,
#   42,
#   32,
#   33,
#   33,
#   33,
#   23,
#   18,
#   18,
#   40,
#   18,
#   36,
#   19,
#   35,
#   46,
#   26,
#   16,
#   17,
#   25,
#   36,
#   17,
#   23,
#   33,
#   27,
#   24,
#   32,
#   43,
#   34,
#   49,
#   33],
#  'follow': ['male_f',
#   'female_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'female_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'female_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_t',
#   'female_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'female_t',
#   'female_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'female_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_f',
#   'male_f',
#   'male_t',
#   'male_t',
#   'male_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'female_t',
#   'male_f',
#   'male_t',
#   'male_t',
#   'male_t',
#   'male_f',
#   'male_t',
#   'female_t',
#   'male_t',
#   'male_f',
#   'female_t',
#   'male_f']}

# %%
df = pd.DataFrame(data)
df
# Out:
#     gender  age    follow
# 0     male   26    male_f
# 1     male   29  female_t
# 2     male   34    male_t
# 3     male   25  female_t
# 4     male   42  female_t
# ..     ...  ...       ...
# 395   male   32  female_t
# 396   male   43    male_t
# 397   male   34    male_f
# 398   male   49  female_t
# 399   male   33    male_f
#
# [400 rows x 3 columns]

# %%
df.to_csv("tiktok_dataset")
